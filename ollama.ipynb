# %% [markdown]
# <a href="https://colab.research.google.com/github/whobcode/embed/blob/main/ollama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -fsSL https://ollama.ai/install.sh | sh

# %%
# !wget -q https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar -xzf ngrok-v3-stable-linux-amd64.tgz ngrok

# %%
# !./ngrok config add-authtoken "34aDC7DWAuVoxzYZ9FHF1lnfpwV_2hXpDp2WXKR6T4UQPYgh5"
# !./ngrok config add-authtoken "ep_34cZihyOaYWJvSB3ahjjAfLwoKa"

# %%
# !ollama serve & ./ngrok http 11434 --host-header="localhost:11434" --log stdout & sleep 5s && ollama run whobcode/mother:latest
# Out:
# INFO[10-26|22:19:48] no configuration paths supplied
# INFO[10-26|22:19:48] using configuration at default config path path=/root/.config/ngrok/ngrok.yml
# INFO[10-26|22:19:48] open config file                         path=/root/.config/ngrok/ngrok.yml err=nil
# ...
